# %% [markdown]
# <a href="https://colab.research.google.com/github/myappcubic/leet-code-problem-set/blob/main/Dynamic_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 42**
# Gathering Rain Water
#
# ![Screenshot 2024-04-01 at 07.55.10.png](data:image/png;base64,...)

# %%
from typing import List

# %%
class Solution:
    def trap(self, height: List[int]) -> int:

        n = len(height)
        res = 0
        if n == 0:
            return res

        max_left = [0] * n
        max_right = [0] * n
        max_left[0] = height[0]
        max_right[n-1] = height[n-1]

        for i in range(1, n-1):
            if height[i] > max_left[i-1]:
                max_left[i] = height[i]
            else:
                max_left[i] = max_left[i-1]
        for i in range(n-2, -1, -1):
            if height[i] > max_right[i+1]:
                max_right[i] = height[i]
            else:
                max_right[i] = max_right[i+1]
        for i in range(1, n-1):
            res += min(max_left[i], max_right[i]) - height[i]

        return res
